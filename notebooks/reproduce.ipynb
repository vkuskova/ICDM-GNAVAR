# %% [markdown]
# # Reproduce: "When Are Neural Interaction Discoveries Real?"
#
# Two paths:
# - **Path A (default, ~30s, no GPU):** verify every paper number against the committed `results/` artifacts.
# - **Path B (GPU, hours):** regenerate the artifacts from scratch, then verify.
#
# Run the first cell for Path A. Path B cells are clearly marked and optional.

# %% [markdown]
# ## Path A — verify committed artifacts (no GPU)

# %%
# Path A: verify every paper number against committed artifacts (no GPU).
# Run this AFTER unzipping the downloaded repo and cd-ing into it.
# !pip -q install numpy pandas
# !python verify_paper_numbers.py

# %% [markdown]
# ## Path B — regenerate artifacts from scratch (GPU, optional)
#
# Each experiment script writes to `results/<experiment>/`. After regenerating, re-run Path A to confirm the new artifacts still pass every check. Expect small seed/hardware variation in the *seed-sensitive* quantities (checked as ranges, not point values); the exact-checked quantities (recovery counts, parameter counts, rank orderings) should match.
#
# > NOTE: Path B requires a GPU runtime and the raw datasets (see `data/README.md` for sources). Heavy runs (synthetic T=100k, gating-value) take the longest.

# %%
# !pip -q install torch scikit-learn numpy pandas
# Path B regenerates artifacts. Each experiment is its own notebook in this folder
# (experiment1, experiment2, experiment_gating_value, experiment_beijing,
#  experiment_rv, experiment_wdi_resource_curse). Open any with the Colab badge
# and Run all; its bootstrap cell resolves paths. See notebooks/README.md for the
# notebook -> results-folder map and which raw datasets each needs. After regenerating,
# re-run Path A (verify_paper_numbers.py) to confirm the new artifacts pass every check.
print('Path B: run a per-experiment notebook (see notebooks/README.md), then re-run Path A.')
